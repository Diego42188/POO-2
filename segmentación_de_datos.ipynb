# %% [markdown]
# #Creacion de una base de datos
#
# creacion de una base de datos

# %%
estudiantes = {"Dante":[2,3,5,4],
       "zamora":[4,6,9,10],
       "penemike":[2,5,1,11],
       "Palafox":[2,5,7,15],
       "Eduard":[2,5,34,67]}
type(estudiantes)
# Out:
# dict

# %% [markdown]
# creamos un diccionario donde a traves del mismo podemos crear una base de datos

# %%
df_estudiantes = pd.DataFrame(estudiantes)
df_estudiantes
# Out:
#    Dante  zamora  penemike  Palafox  Eduard
# 0      2       4         2        2       2
# 1      3       6         5        5       5
# 2      5       9         1        7      34
# 3      4      10        11       15      67

# %% [markdown]
# API:Las API son mecanismos que permiten a dos componentes de software comunicarse entre sí mediante un conjunto de definiciones y protocolos. Por ejemplo, el sistema de software del instituto de meteorología contiene datos meteorológicos diarios.
# fuente:[API](https://aws.amazon.com/es/what-is/api/#:~:text=Las%20API%20son%20mecanismos%20que,meteorolog%C3%ADa%20contiene%20datos%20meteorol%C3%B3gicos%20diarios.)

# %%
import yfinance as yf

# %%
ticker = "AAPL"

aapl = yf.download(ticker, "2020-01-01", end = "2024-01-01")
aapl
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   74.059998   75.150002   73.797501   75.087502   73.059433
# 2020-01-03   74.287498   75.144997   74.125000   74.357498   72.349152
# 2020-01-06   73.447502   74.989998   73.187500   74.949997   72.925629
# 2020-01-07   74.959999   75.224998   74.370003   74.597504   72.582634
# 2020-01-08   74.290001   76.110001   74.290001   75.797501   73.750252
# ...                ...         ...         ...         ...         ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  193.353287
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  192.803986
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  192.903839
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  193.333298
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  192.284637
#
#                Volume
# Date
# 2020-01-02  135480400
# 2020-01-03  146322800
# 2020-01-06  118387200
# 2020-01-07  108872000
# 2020-01-08  132079200
# ...               ...
# 2023-12-22   37122800
# 2023-12-26   28919300
# 2023-12-27   48087700
# 2023-12-28   34049900
# 2023-12-29   42628800
#
# [1006 rows x 6 columns]
